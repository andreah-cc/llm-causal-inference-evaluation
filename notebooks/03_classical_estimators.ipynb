# %% [markdown]
# # Classical Causal Estimator Baselines
#
# This notebook demonstrates **Module 3** of the capstone workflow. The baseline estimators are implemented in `src/estimators/` and are used to contextualize the LLM-based ATE estimates.

# %%
from pathlib import Path
import sys
import pandas as pd

cwd = Path.cwd()
PROJECT_ROOT = cwd.parent if cwd.name == "notebooks" else cwd
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.estimators.regression_adjustment import baseline_ra_plugin
from src.estimators.ipw import baseline_ipw
from src.estimators.stratification import baseline_ps_stratification
from src.estimators.matching import baseline_ps_matching
from src.estimators.aipw import baseline_aipw_dr

# %% [markdown]
# ## Available baselines
#
# - Regression adjustment (RA)
# - Inverse probability weighting (IPW)
# - Propensity-score stratification
# - Nearest-neighbor propensity-score matching
# - Augmented IPW / doubly robust estimation (AIPW/DR)
#
# All propensity-based methods share the same logistic propensity-score and overlap-diagnostic utilities.

# %%
# Example (replace with a CSV path from data/simulated/)
# df = pd.read_csv(PROJECT_ROOT / "data" / "simulated" / "Engine_1_tau_1.csv")
#
# results = {
#     "RA": baseline_ra_plugin(df),
#     "IPW": baseline_ipw(df),
#     "PS Stratification": baseline_ps_stratification(df),
#     "PS Matching": baseline_ps_matching(df),
#     "AIPW": baseline_aipw_dr(df),
# }
# results
